# %%
# !pip install pandas
# !pip install sqlalchemy
# !pip install psycopg2-binary
# !pip install mysql-connector-python
# !pip install pyodbc       # DRIVER AZURE PARA MACOS: https://learn.microsoft.com/en-us/sql/connect/odbc/download-odbc-driver-for-sql-server?view=sql-server-ver15#download-for-linux-and-macos

# %%
from sqlalchemy import create_engine, text
import psycopg2
import pandas as pd
from datetime import datetime as dt
import random
import os
from dotenv import load_dotenv

# %% [markdown]
# <br>
#
# # CONEXIÓN CON LA BASE DE DATOS MYSQL

# %% [markdown]
# ### Desplegada en AWS

# %%
load_dotenv()

RENDER_USER = os.getenv('RENDER_USER')
RENDER_PASS = os.getenv('RENDER_PASS')
RENDER_HOST = os.getenv('RENDER_HOST')
RENDER_PORT = os.getenv('RENDER_PORT')
RENDER_NAME = os.getenv('RENDER_NAME')

# %%
db_url = f'postgresql+psycopg2://{RENDER_USER}:{RENDER_PASS}@{RENDER_HOST}:{RENDER_PORT}/{RENDER_NAME}'
engine = create_engine(db_url)

# %% [markdown]
# ### Comprobar que la conexión ha resultado con éxito

# %%
psycopg2_conn = """psycopg2.connect(
    database='desafio_dgp8',
    user=RENDER_USER,
    password=RENDER_PASS,
    host=RENDER_HOST,
    port=RENDER_PORT
)"""

# %%
query = """
        SELECT table_name 
        FROM information_schema.tables 
        WHERE table_schema = 'public'
        """
with eval(psycopg2_conn) as conn, conn.cursor() as cur:
    # Ejecuta la consulta SQL para crear la tabla
    cur.execute(query)
    tables_name = [row[0] for row in cur.fetchall()]
    
tables_name, len(tables_name)
# Out:
# (['Types',
#   'Contracted_services',
#   'Facilities',
#   'Locations',
#   'Service_companies',
#   'EducationalCenter',
#   'Amenities',
#   'Service_Provisions',
#   'Location_amenities',
#   'Events',
#   'Guests'],
#  11)

# %%
# from sqlalchemy import text
# from sqlalchemy.orm import sessionmaker

# Session = sessionmaker(bind=engine)
# session = Session()

# # Define la consulta SQL para eliminar la tabla si existe
# table_name = 'Organizations'
# sql = f'DROP TABLE IF EXISTS "{table_name}"'
# session.execute(text(sql))

# # Confirma los cambios en la base de datos
# session.commit()
# session.close()

# %% [markdown]
# <br>
#
# # POBLAR DB CON DATOS

# %% [markdown]
# <br>
#
# ### Poblar Tabla de Facilities

# %%
# create_table_sql = """
#     CREATE TABLE IF NOT EXISTS "Facilities" (
#         "id" SERIAL PRIMARY KEY,
#         "name" VARCHAR(255),
#         "address" VARCHAR(255),
#         "createdAt" TIMESTAMP NOT NULL,
#         "updatedAt" TIMESTAMP NOT NULL
#     )
# """

# with eval(psycopg2_conn) as conn, conn.cursor() as cur:
#     cur.execute(create_table_sql)

# %%
# columnas = pd.read_sql_table('Facilities', con=engine).columns

# facilities_excel = pd.read_csv('../data/excel/Facilities.csv')
# facilities_excel['createdAt'] = pd.to_datetime(dt.date(dt.today()))
# facilities_excel['updatedAt'] = pd.to_datetime(dt.date(dt.today()))
# facilities_excel.columns = columnas
# facilities_excel = facilities_excel.drop('id', axis=1)

# %%
# facilities_excel.to_sql('Facilities', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_table('Facilities', con=engine)
# Out:
#    id       name                                           address  createdAt  \
# 0   1       Edem             Plaça de L'aigua, s/n, 46024 Valencia 2023-09-27
# 1   2  Lanzadera  Carrer del Moll de la Duana, s/n, 46024 Valencia 2023-09-27
# 2   3     Angels                     Sc Puerto, 13, 46024 Valencia 2023-09-27
#
#    updatedAt
# 0 2023-09-27
# 1 2023-09-27
# 2 2023-09-27

# %% [markdown]
# <br>
#
# ### Poblar Tabla de Locations

# %%
# create_table_sql = """
#     CREATE TABLE IF NOT EXISTS "Locations" (
#         "id" SERIAL PRIMARY KEY,
#         "facility_id" INT NOT NULL REFERENCES "Facilities"("id"),
#         "meeting_room" VARCHAR(255),
#         "capacity" INT,
#         "description" VARCHAR(255),
#         "createdAt" TIMESTAMP NOT NULL,
#         "updatedAt" TIMESTAMP NOT NULL
#     );
# """

# with eval(psycopg2_conn) as conn, conn.cursor() as cur:
#     cur.execute(create_table_sql)

# %%
# columnas = pd.read_sql_table('Locations', con=engine).columns

# locations_excel = pd.read_csv('../data/excel/Locations.csv')
# locations_excel['createdAt'] = pd.to_datetime(dt.date(dt.today()))
# locations_excel['updatedAt'] = pd.to_datetime(dt.date(dt.today()))
# locations_excel.columns = columnas
# locations_excel = locations_excel.drop('id', axis=1)

# %%
# locations_excel.to_sql('Locations', con=engine, if_exists='append', index=False)
# Out:
# 44

# %%
pd.read_sql_table('Locations', con=engine)
# Out:
#     id  facility_id meeting_room  capacity                 description  \
# 0    1            1        P-001        50         Planta 0, Pasillo 1
# 1    2            1        P-101        50         Planta 1, Pasillo 1
# 2    3            1        P-201        50         Planta 2, Pasillo 1
# 3    4            1        A-001        60       Planta 0, Auditorio 1
# 4    5            1        A-101        60       Planta 1, Auditorio 1
# 5    6            1        A-102        50       Planta 1, Auditorio 2
# 6    7            1        A-201        40       Planta 2, Auditorio 1
# 7    8            1        A-202        40       Planta 2, Auditorio 2
# 8    9            1        L-101        20            Planta 1, Aula 1
# 9   10            1        L-102        20            Planta 1, Aula 2
# 10  11            1        L-103        20            Planta 1, Aula 3
# 11  12            1        L-104        20            Planta 1, Aula 4
# 12  13            1        L-201        20            Planta 2, Aula 1
# 13  14            1        L-202        20            Planta 2, Aula 2
# 14  15            1        L-203        20            Planta 2, Aula 3
# 15  16            1        L-204        20            Planta 2, Aula 4
# 16  17            1        M-101         8  Planta 1, Sala reuniones 1
# 17  18            1        M-102        10  Planta 1, Sala reuniones 2
# 18  19            1        M-201        10  Planta 2, Sala reuniones 1
# 19  20            1        M-202        10  Planta 2, Sala reuniones 2
# 20  21            1        M-203        12  Planta 2, Sala reuniones 3
# 21  22            1        M-204        12  Planta 2, Sala reuniones 4
# 22  23            2        P-001        50                 P00_Pasillo
# 23  24            2        P-101        50                 P01_Pasillo
# 24  25            2        P-201        50                 P02_Pasillo
# 25  26            2        A-001        60            P00_Auditorio_01
# 26  27            2        A-101        60            P01_Auditorio_01
# 27  28            2        A-102        50            P01_Auditorio_02
# 28  29            2        A-201        40            P02_Auditorio_01
# 29  30            2        A-202        40            P02_Auditorio_02
# 30  31            2        L-101        20                 P01_Aula_01
# 31  32            2        L-102        20                 P01_Aula_02
# 32  33            2        L-103        20                 P01_Aula_03
# 33  34            2        L-104        20                 P01_Aula_04
# 34  35            2        L-201        20                 P02_Aula_01
# 35  36            2        L-202        20                 P02_Aula_02
# 36  37            2        L-203        20                 P02_Aula_03
# 37  38            2        L-204        20                 P02_Aula_04
# 38  39            2        M-101         8       P01_Sala_Reuniones_01
# 39  40            2        M-102        10       P01_Sala_Reuniones_02
# 40  41            2        M-201        10       P02_Sala_Reuniones_01
# 41  42            2        M-202        10       P02_Sala_Reuniones_02
# 42  43            2        M-203        12       P02_Sala_Reuniones_03
# 43  44            2        M-204        12       P02_Sala_Reuniones_04
#
#     createdAt  updatedAt
# 0  2023-09-27 2023-09-27
# 1  2023-09-27 2023-09-27
# 2  2023-09-27 2023-09-27
# 3  2023-09-27 2023-09-27
# 4  2023-09-27 2023-09-27
# 5  2023-09-27 2023-09-27
# 6  2023-09-27 2023-09-27
# 7  2023-09-27 2023-09-27
# 8  2023-09-27 2023-09-27
# 9  2023-09-27 2023-09-27
# 10 2023-09-27 2023-09-27
# 11 2023-09-27 2023-09-27
# 12 2023-09-27 2023-09-27
# 13 2023-09-27 2023-09-27
# 14 2023-09-27 2023-09-27
# 15 2023-09-27 2023-09-27
# 16 2023-09-27 2023-09-27
# 17 2023-09-27 2023-09-27
# 18 2023-09-27 2023-09-27
# 19 2023-09-27 2023-09-27
# 20 2023-09-27 2023-09-27
# 21 2023-09-27 2023-09-27
# 22 2023-09-27 2023-09-27
# 23 2023-09-27 2023-09-27
# 24 2023-09-27 2023-09-27
# 25 2023-09-27 2023-09-27
# 26 2023-09-27 2023-09-27
# 27 2023-09-27 2023-09-27
# 28 2023-09-27 2023-09-27
# 29 2023-09-27 2023-09-27
# 30 2023-09-27 2023-09-27
# 31 2023-09-27 2023-09-27
# 32 2023-09-27 2023-09-27
# 33 2023-09-27 2023-09-27
# 34 2023-09-27 2023-09-27
# 35 2023-09-27 2023-09-27
# 36 2023-09-27 2023-09-27
# 37 2023-09-27 2023-09-27
# 38 2023-09-27 2023-09-27
# 39 2023-09-27 2023-09-27
# 40 2023-09-27 2023-09-27
# 41 2023-09-27 2023-09-27
# 42 2023-09-27 2023-09-27
# 43 2023-09-27 2023-09-27

# %% [markdown]
# <br>
#
# ### Poblar Tabla de Amenities

# %%
# create_table_sql = """
#     CREATE TABLE IF NOT EXISTS "Amenities" (
#         "id" SERIAL PRIMARY KEY,
#         "name" VARCHAR(255),
#         "createdAt" TIMESTAMP NOT NULL,
#         "updatedAt" TIMESTAMP NOT NULL
#     );
# """

# with eval(psycopg2_conn) as conn, conn.cursor() as cur:
#     cur.execute(create_table_sql)

# %%
# columnas = pd.read_sql_table('Amenities', con=engine).columns

# amenities_excel = pd.read_csv('../data/excel/Amenities.csv')
# amenities_excel['createdAt'] = pd.to_datetime(dt.date(dt.today()))
# amenities_excel['updatedAt'] = pd.to_datetime(dt.date(dt.today()))
# amenities_excel.columns = columnas
# amenities_excel = amenities_excel.drop('id', axis=1)

# %%
# amenities_excel.to_sql('Amenities', con=engine, if_exists='append', index=False)
# Out:
# 4

# %%
pd.read_sql_table('Amenities', con=engine)
# Out:
#    id       name  createdAt  updatedAt
# 0   1    Butacas 2023-09-27 2023-09-27
# 1   2      Atril 2023-09-27 2023-09-27
# 2   3   Pantalla 2023-09-27 2023-09-27
# 3   4  Proyector 2023-09-27 2023-09-27

# %% [markdown]
# <br>
#
# ### Poblar Tabla de Location_amenities

# %%
# create_table_sql = """
#     CREATE TABLE IF NOT EXISTS "Location_amenities" (
#         "id" SERIAL PRIMARY KEY,
#         "location_id" INT NOT NULL REFERENCES "Locations"("id"),
#         "amenities_id" INT NOT NULL REFERENCES "Amenities"("id"),
#         "createdAt" TIMESTAMP NOT NULL,
#         "updatedAt" TIMESTAMP NOT NULL
#     );
# """

# with eval(psycopg2_conn) as conn, conn.cursor() as cur:
#     cur.execute(create_table_sql)

# %%
# columnas = pd.read_sql_table('Location_amenities', con=engine).columns

# location_amenities_excel = pd.read_csv('../data/excel/Local_amenities.csv')
# location_amenities_excel['createdAt'] = pd.to_datetime(dt.date(dt.today()))
# location_amenities_excel['updatedAt'] = pd.to_datetime(dt.date(dt.today()))
# location_amenities_excel.columns = columnas
# location_amenities_excel = location_amenities_excel.drop('id', axis=1)
# location_amenities_excel

# %%
# location_amenities_excel.to_sql('Location_amenities', con=engine, if_exists='append', index=False)
# Out:
# 90

# %%
pd.read_sql_table('Location_amenities', con=engine)
# Out:
#     id  location_id  amenities_id  createdAt  updatedAt
# 0    1            1             3 2023-09-27 2023-09-27
# 1    2            2             3 2023-09-27 2023-09-27
# 2    3            3             3 2023-09-27 2023-09-27
# 3    4            4             1 2023-09-27 2023-09-27
# 4    5            4             2 2023-09-27 2023-09-27
# ..  ..          ...           ...        ...        ...
# 85  86           40             3 2023-09-27 2023-09-27
# 86  87           41             3 2023-09-27 2023-09-27
# 87  88           42             3 2023-09-27 2023-09-27
# 88  89           43             3 2023-09-27 2023-09-27
# 89  90           44             3 2023-09-27 2023-09-27
#
# [90 rows x 5 columns]

# %% [markdown]
# <br>
#
# ### Poblar Tabla de Events

# %%
# create_table_sql = """
#     CREATE TABLE IF NOT EXISTS "Events" (
#         "id" SERIAL PRIMARY KEY,
#         "location_id" INT NOT NULL REFERENCES "Locations"("id"),
#         "dateTime" TIMESTAMP,
#         "duration_min" INT,
#         "type" VARCHAR(255),
#         "banner" VARCHAR(255),
#         "speacker" VARCHAR(255),
#         "description" VARCHAR(255),
#         "title" VARCHAR(255),
#         "createdAt" TIMESTAMP NOT NULL,
#         "updatedAt" TIMESTAMP NOT NULL
#     );
# """

# with eval(psycopg2_conn) as conn, conn.cursor() as cur:
#     cur.execute(create_table_sql)

# %%
# columnas = pd.read_sql_table('Events', con=engine).columns


# events_excel = pd.read_csv('../data/excel/Events.csv')
# events_excel['speacker'] = ['Borja Astarloa', 'Isabel López', 'EDEM', 'Sònia Valiente', 'Mar Pedroche', 'Lanzadera']
# events_excel['createdAt'] = pd.to_datetime(dt.date(dt.today()))
# events_excel['updatedAt'] = pd.to_datetime(dt.date(dt.today()))
# dict_col = {
#     'Id': 'id',
#     'Location_id': 'location_id',
#     'DateTime': 'dateTime',
#     'Duration_min': 'duration_min',
#     'Type': 'type',
#     'Banner': 'banner',
#     'Description': 'description',
#     'Title': 'title',
#     'speacker': 'speacker'
# }
# events_excel = events_excel.rename(dict_col, axis=1)
# events_excel = events_excel.drop('id', axis=1)
# events_excel

# %%
# events_excel.to_sql('Events', con=engine, if_exists='append', index=False)
# Out:
# 6

# %%
pd.read_sql_table('Events', con=engine)
# Out:
#    id  location_id            dateTime  duration_min       type banner  \
# 0   1           27 2023-10-23 16:00:00            90   Finanzas   None
# 1   2            6 2023-11-03 17:30:00            60  Marketing   None
# 2   3            5 2023-09-29 18:00:00           120   Docencia   None
# 3   4           28 2023-09-15 12:00:00            90         IT   None
# 4   5            5 2023-09-01 18:00:00            60  Liderazgo   None
# 5   6            1 2023-11-20 18:00:00           120     Empleo   None
#
#          speacker                                        description  \
# 0  Borja Astarloa  Borja Astarloa, director de JP Morgan, habla s...
# 1    Isabel López  Isabel López nos hablará sobre el desarrollo d...
# 2            EDEM  Aprovecha los días que EDEM abre sus puertas p...
# 3  Sònia Valiente  Sònia Valiente nos dará las claves más importa...
# 4    Mar Pedroche  Mar Pedroche nos mostrará las aplicaciones y p...
# 5       Lanzadera  Ven a conocer a una selección de empresas del ...
#
#                                                title  createdAt  updatedAt
# 0            Planteamientos financieros y económicos 2023-09-27 2023-09-27
# 1  Claves para mejorar la experiencia del cliente... 2023-09-27 2023-09-27
# 2                                 Open Day Grado ADE 2023-09-27 2023-09-27
# 3                 Comunicación en entornos digitales 2023-09-27 2023-09-27
# 4  Conocer herramientas que mejoran la productivi... 2023-09-27 2023-09-27
# 5                                  Foro de Empleo IT 2023-09-27 2023-09-27

# %% [markdown]
# <br>
#
# ### Poblar Tabla de Guests

# %%
# create_table_sql = """
#     CREATE TABLE IF NOT EXISTS "Guests" (
#         "id" SERIAL PRIMARY KEY,
#         "event_id" INT NOT NULL REFERENCES "Events"("id"),
#         "name" VARCHAR(255),
#         "email" VARCHAR(255),
#         "createdAt" TIMESTAMP NOT NULL,
#         "updatedAt" TIMESTAMP NOT NULL
#     );
# """

# with eval(psycopg2_conn) as conn, conn.cursor() as cur:
#     cur.execute(create_table_sql)

# %%
# columnas = pd.read_sql_table('Guests', con=engine).columns

# guests_excel = pd.read_csv('../data/excel/Guest.csv')
# guests_excel['createdAt'] = pd.to_datetime(dt.date(dt.today()))
# guests_excel['updatedAt'] = pd.to_datetime(dt.date(dt.today()))
# guests_excel.columns = columnas
# guests_excel = guests_excel.drop('id', axis=1)
# guests_excel

# %%
# guests_excel.to_sql('Guests', con=engine, if_exists='append', index=False)
# Out:
# 24

# %%
pd.read_sql_table('Guests', con=engine)
# Out:
#     id  event_id                 name                          email  \
# 0    1         1       Antonio García      antoniogarcia@example.com
# 1    2         1      Carmen Martínez     carmenmartinez@example.com
# 2    3         1      Francisco López     franciscolopez@example.com
# 3    4         1          María Pérez         mariaperez@example.com
# 4    5         1         Juan Sánchez        juansanchez@example.com
# 5    6         1           Ana Torres          anatorres@example.com
# 6    7         2            José Ruiz            josruiz@example.com
# 7    8         2         Isabel Gómez        isabelgomez@example.com
# 8    9         2        Manuel Romero       manuelromero@example.com
# 9   10         2         Laura Suárez        laurasuarez@example.com
# 10  11         3       David González      davidgonzalez@example.com
# 11  12         3      Marta Hernández     martahernandez@example.com
# 12  13         3       Carlos Jiménez      carlosjimenez@example.com
# 13  14         4           Paula Díaz          pauladiaz@example.com
# 14  15         4  Miguel Ángel Moreno  miguelangelmoreno@example.com
# 15  16         5        Lucía Álvarez       luciaalvarez@example.com
# 16  17         5      Pablo Gutiérrez     pablogutierrez@example.com
# 17  18         5         Sofía Castro        sofiacastro@example.com
# 18  19         5     Alejandro Ortega    alejandroortega@example.com
# 19  20         5        Andrea Flores       andreaflores@example.com
# 20  21         6        Javier Medina       javiermedina@example.com
# 21  22         6         Natalia Vega        nataliavega@example.com
# 22  23         6        Sergio Torres       sergiotorres@example.com
# 23  24         6        Elena Serrano       elenaserrano@example.com
#
#     createdAt  updatedAt
# 0  2023-09-27 2023-09-27
# 1  2023-09-27 2023-09-27
# 2  2023-09-27 2023-09-27
# 3  2023-09-27 2023-09-27
# 4  2023-09-27 2023-09-27
# 5  2023-09-27 2023-09-27
# 6  2023-09-27 2023-09-27
# 7  2023-09-27 2023-09-27
# 8  2023-09-27 2023-09-27
# 9  2023-09-27 2023-09-27
# 10 2023-09-27 2023-09-27
# 11 2023-09-27 2023-09-27
# 12 2023-09-27 2023-09-27
# 13 2023-09-27 2023-09-27
# 14 2023-09-27 2023-09-27
# 15 2023-09-27 2023-09-27
# 16 2023-09-27 2023-09-27
# 17 2023-09-27 2023-09-27
# 18 2023-09-27 2023-09-27
# 19 2023-09-27 2023-09-27
# 20 2023-09-27 2023-09-27
# 21 2023-09-27 2023-09-27
# 22 2023-09-27 2023-09-27
# 23 2023-09-27 2023-09-27

# %% [markdown]
# <br>
#
# ### Poblar Tabla de Service_companies

# %%
# create_table_sql = """
#     CREATE TABLE IF NOT EXISTS "Service_companies" (
#         "id" SERIAL PRIMARY KEY,
#         "name" VARCHAR(255),
#         "email" VARCHAR(255),
#         "tel" INT,
#         "speciality" VARCHAR(255),
#         "department" VARCHAR(255),
#         "createdAt" TIMESTAMP NOT NULL,
#         "updatedAt" TIMESTAMP NOT NULL
#     );
# """

# with eval(psycopg2_conn) as conn, conn.cursor() as cur:
#     cur.execute(create_table_sql)

# %%
# columnas = pd.read_sql_table('Service_companies', con=engine).columns

# service_companies_excel = pd.read_csv('../data/excel/Service_company.csv')
# service_companies_excel['createdAt'] = pd.to_datetime(dt.date(dt.today()))
# service_companies_excel['updatedAt'] = pd.to_datetime(dt.date(dt.today()))
# service_companies_excel.columns = columnas
# service_companies_excel = service_companies_excel.drop('id', axis=1)
# service_companies_excel

# %%
# service_companies_excel.to_sql('Service_companies', con=engine, if_exists='append', index=False)
# Out:
# 9

# %%
pd.read_sql_table('Service_companies', con=engine)
# Out:
#    id                        name                  email        tel  \
# 0   1                    Colevisa  colevisa@colevisa.com  963169106
# 1   2                      Salsia         info@salsia.es  960089454
# 2   3              JMC Fotografos            info@jmc.es  963363914
# 3   4  Estudio fotografico Lorsil   fotolorsil@gmail.com  963345422
# 4   5                 MA's Events    masevents@gmail.com  662332287
# 5   6                   EV-Events     evevents@gmail.com  661894202
# 6   7           Unanime Creativos  creativos@unanime.com  963899098
# 7   8   Agencia Marketing Digital  markdig@agenciamk.com  606817508
# 8   9            Edem - Logística       infoedem@edem.es  963531065
#
#    speciality department  createdAt  updatedAt
# 0    catering     Ventas 2023-09-27 2023-09-27
# 1    catering     Ventas 2023-09-27 2023-09-27
# 2  fotografia     Ventas 2023-09-27 2023-09-27
# 3  fotografia     Ventas 2023-09-27 2023-09-27
# 4  montadores     Ventas 2023-09-27 2023-09-27
# 5  montadores     Ventas 2023-09-27 2023-09-27
# 6      diseño     Ventas 2023-09-27 2023-09-27
# 7      diseño     Ventas 2023-09-27 2023-09-27
# 8   educación  Logística 2023-09-27 2023-09-27

# %% [markdown]
# <br>
#
# ### Poblar Tabla de Service_Provisions

# %%
# create_table_sql = """
#     CREATE TABLE IF NOT EXISTS "Service_Provisions" (
#         "id" SERIAL PRIMARY KEY,
#         "name" VARCHAR(255),
#         "description" VARCHAR(255),
#         "createdAt" TIMESTAMP NOT NULL,
#         "updatedAt" TIMESTAMP NOT NULL
#     );
# """

# with eval(psycopg2_conn) as conn, conn.cursor() as cur:
#     cur.execute(create_table_sql)

# %%
# columnas = pd.read_sql_table('Service_Provisions', con=engine).columns

# service_Provisions_excel = pd.read_csv('../data/excel/Service_Provision.csv')
# service_Provisions_excel['createdAt'] = pd.to_datetime(dt.date(dt.today()))
# service_Provisions_excel['updatedAt'] = pd.to_datetime(dt.date(dt.today()))
# service_Provisions_excel.columns = columnas
# service_Provisions_excel = service_Provisions_excel.drop('id', axis=1)
# service_Provisions_excel

# %%
# service_Provisions_excel.to_sql('Service_Provisions', con=engine, if_exists='append', index=False)
# Out:
# 5

# %%
pd.read_sql_table('Service_Provisions', con=engine)
# Out:
#    id                  name  \
# 0   1  Servicio de cátering
# 1   2   Cobertura Logística
# 2   3      Material gráfico
# 3   4      Monaje de stands
# 4   5            Fotografía
#
#                                          description  createdAt  updatedAt
# 0           Servicio de café, refrescos y bocadillos 2023-09-27 2023-09-27
# 1     Servicio de recepción y apoyo a incidencias IT 2023-09-27 2023-09-27
# 2       Elaboración de Flyer y cartel 0,90 x 1,80 cm 2023-09-27 2023-09-27
# 3  Servicio, montaje, desmontaje y retirada de st... 2023-09-27 2023-09-27
# 4  Reportaje fotográfico de evento de duración má... 2023-09-27 2023-09-27

# %% [markdown]
# <br>
#
# ### Poblar Tabla de Contracted_services

# %%
# create_table_sql = """
#     CREATE TABLE IF NOT EXISTS "Contracted_services" (
#         "id" SERIAL PRIMARY KEY,
#         "service_id" INT NOT NULL REFERENCES "Service_Provisions"("id"),
#         "event_id" INT NOT NULL REFERENCES "Events"("id"),
#         "cost" DECIMAL,
#         "paid" DECIMAL,
#         "service_company_id" INT REFERENCES "Service_companies"("id"),
#         "createdAt" TIMESTAMP NOT NULL,
#         "updatedAt" TIMESTAMP NOT NULL
#     );
# """

# with eval(psycopg2_conn) as conn, conn.cursor() as cur:
#     cur.execute(create_table_sql)

# %%
# columnas = pd.read_sql_table('Contracted_services', con=engine).columns

# contracted_services_excel = pd.read_csv('../data/excel/Contracted_Service.csv')
# contracted_services_excel['Cost'] = contracted_services_excel['Cost'].str.replace(',', '.').astype(float)
# contracted_services_excel['Paid'] = contracted_services_excel['Paid'].str.replace(',', '.').astype(float)
# pop_col = contracted_services_excel['ServiceCompany_id']
# contracted_services_excel = contracted_services_excel.drop('ServiceCompany_id', axis=1)
# contracted_services_excel.insert(5, 'ServiceCompany_id', pop_col)
# contracted_services_excel['createdAt'] = pd.to_datetime(dt.date(dt.today()))
# contracted_services_excel['updatedAt'] = pd.to_datetime(dt.date(dt.today()))
# contracted_services_excel.columns = columnas
# contracted_services_excel = contracted_services_excel.drop('id', axis=1)
# contracted_services_excel

# %%
# contracted_services_excel.to_sql('Contracted_services', con=engine, if_exists='append', index=False)
# Out:
# 20

# %%
pd.read_sql_table('Contracted_services', con=engine)
# Out:
#     id  service_id  event_id    cost   paid  service_company_id  createdAt  \
# 0    1           1         1   200.0    NaN                   1 2023-09-27
# 1    2           2         1     NaN    NaN                   9 2023-09-27
# 2    3           3         1   350.0    NaN                   7 2023-09-27
# 3    4           5         1   300.0    NaN                   3 2023-09-27
# 4    5           1         2   200.0    NaN                   1 2023-09-27
# 5    6           2         2     NaN    NaN                   9 2023-09-27
# 6    7           3         2   350.0    NaN                   7 2023-09-27
# 7    8           1         3   200.0    NaN                   1 2023-09-27
# 8    9           2         3     NaN    NaN                   9 2023-09-27
# 9   10           3         3   350.0    NaN                   7 2023-09-27
# 10  11           1         4   200.0  235.0                   1 2023-09-27
# 11  12           2         4     NaN    NaN                   9 2023-09-27
# 12  13           3         4   350.0  415.0                   7 2023-09-27
# 13  14           5         4   300.0  300.0                   3 2023-09-27
# 14  15           1         5   200.0  235.0                   1 2023-09-27
# 15  16           2         5     NaN    NaN                   9 2023-09-27
# 16  17           3         5   350.0  475.2                   7 2023-09-27
# 17  18           3         6   350.0    NaN                   7 2023-09-27
# 18  19           4         6  2500.0    NaN                   6 2023-09-27
# 19  20           5         6   300.0    NaN                   3 2023-09-27
#
#     updatedAt
# 0  2023-09-27
# 1  2023-09-27
# 2  2023-09-27
# 3  2023-09-27
# 4  2023-09-27
# 5  2023-09-27
# 6  2023-09-27
# 7  2023-09-27
# 8  2023-09-27
# 9  2023-09-27
# 10 2023-09-27
# 11 2023-09-27
# 12 2023-09-27
# 13 2023-09-27
# 14 2023-09-27
# 15 2023-09-27
# 16 2023-09-27
# 17 2023-09-27
# 18 2023-09-27
# 19 2023-09-27

# %% [markdown]
# <br>
#
# ### Poblar Tabla de Types

# %%
# create_table_sql = """
#     CREATE TABLE IF NOT EXISTS "Types" (
#         "id" SERIAL PRIMARY KEY,
#         "organization_id" INT,
#         "name" VARCHAR(255),
#         "createdAt" TIMESTAMP NOT NULL,
#         "updatedAt" TIMESTAMP NOT NULL
#     );
# """

# with eval(psycopg2_conn) as conn, conn.cursor() as cur:
#     cur.execute(create_table_sql)

# %%
# columnas = pd.read_sql_table('Types', con=engine).columns

# types_excel = pd.read_csv('../data/excel/Type.csv')
# types_excel['Name'] = types_excel['Name'].drop_duplicates()
# types_excel = types_excel.dropna().reset_index(drop=True)
# types_excel['Organization_id'] = None
# types_excel['createdAt'] = pd.to_datetime(dt.date(dt.today()))
# types_excel['updatedAt'] = pd.to_datetime(dt.date(dt.today()))
# types_excel.columns = columnas
# types_excel = types_excel.drop('id', axis=1)
# types_excel

# %%
# types_excel.to_sql('Types', con=engine, if_exists='append', index=False)
# Out:
# 5

# %%
pd.read_sql_table('Types', con=engine)
# Out:
#    id organization_id                name  createdAt  updatedAt
# 0   1            None  Marina de Empresas 2023-09-27 2023-09-27
# 1   2            None                Otro 2023-09-27 2023-09-27
# 2   3            None            Miembros 2023-09-27 2023-09-27
# 3   4            None            Patronos 2023-09-27 2023-09-27
# 4   5            None    Centro Educativo 2023-09-27 2023-09-27

# %% [markdown]
# <br>
#
# ### Poblar Tabla de Organizations

# %%
# create_table_sql = """
#     CREATE TABLE IF NOT EXISTS "Organizations" (
#         "id" SERIAL PRIMARY KEY,
#         "type_id" INT NOT NULL REFERENCES "Types"("id"),
#         "name" VARCHAR(255),
#         "web" VARCHAR(255),
#         "email" VARCHAR(255),
#         "tel" INT,
#         "position" VARCHAR(255),
#         "sector" VARCHAR(255),
#         "createdAt" TIMESTAMP NOT NULL,
#         "updatedAt" TIMESTAMP NOT NULL
#     );
# """

# with eval(psycopg2_conn) as conn, conn.cursor() as cur:
#     cur.execute(create_table_sql)

# %%
# columnas = pd.read_sql_table('Organizations', con=engine).columns
# type_id = pd.read_sql_table('Types', con=engine)['id']

# organizations_excel = pd.read_csv('../data/excel/Organization.csv', index_col=0)
# organizations_excel['createdAt'] = pd.to_datetime(dt.date(dt.today()))
# organizations_excel['updatedAt'] = pd.to_datetime(dt.date(dt.today()))
# organizations_excel.columns = columnas
# organizations_excel = organizations_excel.drop('id', axis=1)
# organizations_excel

# %%
# organizations_excel.to_sql('Organizations', con=engine, if_exists='append', index=False)
# Out:
# 198

# %%
pd.read_sql_table('Organizations', con=engine)
# Out:
#       id  type_id                                            name  \
# 0      1        1                                       Lanzadera
# 1      2        1                                            Edem
# 2      3        1                                  Angels Capital
# 3      4        1                                             AAA
# 4      5        2  ACS Actividades de Construccion y Servicios SA
# ..   ...      ...                                             ...
# 193  194        5                             Colegio San Antonio
# 194  195        5      Colegio Nuestra Señora de los Desamparados
# 195  196        5                     Universidad Rey Juan Carlos
# 196  197        5                  Universidad Autónoma de Madrid
# 197  198        5               Universidad Politécnica de Madrid
#
#                                                    web  \
# 0                                 https://lanzadera.es
# 1                                      https://edem.eu
# 2                         https://www.angelscapital.es
# 3                          https://www.triplea.edem.es
# 4                             https://www.grupoacs.com
# ..                                                 ...
# 193                      https://colegiosanantonio.com
# 194  https://colegionuestrasenoradelosdesamparados.com
# 195               https://universidadreyjuancarlos.com
# 196            https://universidadautonomademadrid.com
# 197         https://universidadpolitecnicademadrid.com
#
#                                               email        tel position  \
# 0                                 info@lanzadera.es  963568585  General
# 1                                      info@edem.es  963531065  General
# 2                             info@angelscapital.es  963568585  General
# 3                                   triplea@edem.es  963531065  General
# 4                                   acs@empresa.com  913439200  General
# ..                                              ...        ...      ...
# 193                      info@colegiosanantonio.com  964886746  General
# 194  info@colegionuestrasenoradelosdesamparados.com  964091976  General
# 195               info@universidadreyjuancarlos.com  963954427  General
# 196            info@universidadautonomademadrid.com  964208403  General
# 197         info@universidadpolitecnicademadrid.com  964172962  General
#
#                               sector  createdAt  updatedAt
# 0                     Emprendimiento 2023-09-28 2023-09-28
# 1                          Educación 2023-09-28 2023-09-28
# 2                          Inversión 2023-09-28 2023-09-28
# 3    organización sin ánimo de lucro 2023-09-28 2023-09-28
# 4                       Industriales 2023-09-28 2023-09-28
# ..                               ...        ...        ...
# 193                        Educación 2023-09-28 2023-09-28
# 194                        Educación 2023-09-28 2023-09-28
# 195                        Educación 2023-09-28 2023-09-28
# 196                        Educación 2023-09-28 2023-09-28
# 197                        Educación 2023-09-28 2023-09-28
#
# [198 rows x 10 columns]

# %% [markdown]
# <br>
#
# ### Poblar Tabla de EducationalCenter

# %%
# create_table_sql = """
#     CREATE TABLE IF NOT EXISTS "EducationalCenter" (
#         "id" SERIAL PRIMARY KEY,
#         "type_id" INT NOT NULL REFERENCES "Types"("id"),
#         "name" VARCHAR(255),
#         "createdAt" TIMESTAMP NOT NULL,
#         "updatedAt" TIMESTAMP NOT NULL
#     );
# """

# with eval(psycopg2_conn) as conn, conn.cursor() as cur:
#     cur.execute(create_table_sql)

# %%
# columnas = pd.read_sql_table('EducationalCenter', con=engine).columns

# educational_center_excel = pd.read_csv('../data/excel/EducationalCenter.csv')
# educational_center_excel['Type_id'] = 5
# educational_center_excel['createdAt'] = pd.to_datetime(dt.date(dt.today()))
# educational_center_excel['updatedAt'] = pd.to_datetime(dt.date(dt.today()))
# educational_center_excel.columns = columnas
# educational_center_excel = educational_center_excel.drop('id', axis=1)
# educational_center_excel

# %%
# educational_center_excel.to_sql('EducationalCenter', con=engine, if_exists='append', index=False)
# Out:
# 26

# %%
pd.read_sql_table('EducationalCenter', con=engine)
# Out:
#     id  type_id         name  createdAt  updatedAt
# 0    1        5      Colegio 2023-09-27 2023-09-27
# 1    2        5      Colegio 2023-09-27 2023-09-27
# 2    3        5      Colegio 2023-09-27 2023-09-27
# 3    4        5      Colegio 2023-09-27 2023-09-27
# 4    5        5      Colegio 2023-09-27 2023-09-27
# 5    6        5      Colegio 2023-09-27 2023-09-27
# 6    7        5      Colegio 2023-09-27 2023-09-27
# 7    8        5      Colegio 2023-09-27 2023-09-27
# 8    9        5      Colegio 2023-09-27 2023-09-27
# 9   10        5      Colegio 2023-09-27 2023-09-27
# 10  11        5      Colegio 2023-09-27 2023-09-27
# 11  12        5      Colegio 2023-09-27 2023-09-27
# 12  13        5      Colegio 2023-09-27 2023-09-27
# 13  14        5      Colegio 2023-09-27 2023-09-27
# 14  15        5    Instituto 2023-09-27 2023-09-27
# 15  16        5  Universidad 2023-09-27 2023-09-27
# 16  17        5  Universidad 2023-09-27 2023-09-27
# 17  18        5  Universidad 2023-09-27 2023-09-27
# 18  19        5  Universidad 2023-09-27 2023-09-27
# 19  20        5  Universidad 2023-09-27 2023-09-27
# 20  21        5  Universidad 2023-09-27 2023-09-27
# 21  22        5  Universidad 2023-09-27 2023-09-27
# 22  23        5  Universidad 2023-09-27 2023-09-27
# 23  24        5  Universidad 2023-09-27 2023-09-27
# 24  25        5  Universidad 2023-09-27 2023-09-27
# 25  26        5  Universidad 2023-09-27 2023-09-27

# %% [markdown]
# <br>
#
# ### Poblar Tabla de Users

# %%
# create_table_sql = """
#     CREATE TABLE IF NOT EXISTS "Users" (
#         "id" SERIAL PRIMARY KEY,
#         "name" VARCHAR(255),
#         "organization_id" INT NOT NULL REFERENCES "Organizations"("id"),
#         "surname" VARCHAR(255),
#         "email" VARCHAR(255),
#         "password" VARCHAR(255),
#         "tel" INT,
#         "birthdate" TIMESTAMP,
#         "avatar" VARCHAR(255),
#         "confirmed" VARCHAR(255),
#         "file" VARCHAR(255),
#         "course" VARCHAR(255),
#         "country" VARCHAR(255),
#         "interest" VARCHAR(255),
#         "gender" VARCHAR(255),
#         "catchment" VARCHAR(255),
#         "career" VARCHAR(255),
#         "responsibility" VARCHAR(255),
#         "area" VARCHAR(255),
#         "createdAt" TIMESTAMP NOT NULL,
#         "updatedAt" TIMESTAMP NOT NULL
#     );
# """

# with eval(psycopg2_conn) as conn, conn.cursor() as cur:
#     cur.execute(create_table_sql)

# %%
# columnas = pd.read_sql_table('Users', con=engine).columns

# users_excel = pd.read_csv('../data/excel/User.csv')
# users_excel['confirmed'] = [random.choice([0, 1]) for _ in range(len(users_excel['Id']))]
# users_excel['area'] = None
# users_excel['createdAt'] = pd.to_datetime(dt.date(dt.today()))
# users_excel['updatedAt'] = pd.to_datetime(dt.date(dt.today()))
# dict_col = {
#     "Id": "id",
#     "Name": "name",
#     "Organization_id": "organization_id",
#     "Surname": "surname",
#     "Email": "email",
#     "Password": "password",
#     "Tel": "tel",
#     "Birthdate": "birthdate",
#     "Avatar": "avatar",
#     "confirmed": "confirmed",
#     "File": "file",
#     "Course": "course",
#     "Country": "country",
#     "Interests": "interest",
#     "Gender": "gender",
#     "Catchment": "catchment",
#     "Career": "career",
#     "Responsability": "responsibility",
#     "area": "area",
#     "createdAt": "createdAt",
#     "updatedAt": "updatedAt"
# }
# users_excel = users_excel.rename(dict_col, axis=1)
# users_excel = users_excel.drop('id', axis=1)
# users_excel

# %%
# users_excel.to_sql('Users', con=engine, if_exists='append', index=False)
# Out:
# 60

# %%
pd.read_sql_table('Users', con=engine).iloc[:, :-1]
# Out:
#     id          name  organization_id    surname                        email  \
# 0    1        Raquel                2    Cabrera     raquel.cabrera@gmail.com
# 1    2        Manuel                2     Torres      manuel.torres@gmail.com
# 2    3        Manuel                2    Johnson     manuel.johnson@gmail.com
# 3    4         Diego                2  Hernández    diego.hernández@gmail.com
# 4    5         Mario                2     Molina       mario.molina@gmail.com
# 5    6        Javier                2     Thomas      javier.thomas@gmail.com
# 6    7      Fernando                2    Herrero   fernando.herrero@gmail.com
# 7    8       Gabriel                2     Suárez     gabriel.suárez@gmail.com
# 8    9           Ana                2       Vega           ana.vega@gmail.com
# 9   10         Mario                2    Vicente      mario.vicente@gmail.com
# 10  11  Miguel Ángel                2       Cruz         luisa.cruz@gmail.com
# 11  12     Estefanía                2      Silva       isabel.silva@gmail.com
# 12  13        Víctor                2       Ruiz        miguel.ruiz@gmail.com
# 13  14        Adrián                2    Cabrera       josé.cabrera@gmail.com
# 14  15          Sara                2      Silva         raul.silva@gmail.com
# 15  16      Patricia                2    Aguilar   santiago.aguilar@gmail.com
# 16  17          Alan                2   González   gustavo.gonzález@gmail.com
# 17  18        Jorman                2      Reyes      gustavo.reyes@gmail.com
# 18  19      Santiago                2  Hernández  gustavo.hernández@gmail.com
# 19  20     Alejandro                2     Torres      javier.torres@gmail.com
# 20  21        Rafael                2     Torres      rafael.torres@gmail.com
# 21  22        Silvia                2     Campos       clara.campos@gmail.com
# 22  23        Andrés                2   Iglesias   ricardo.iglesias@gmail.com
# 23  24       Gustavo              173  Hernández  gustavo.hernández@gmail.com
# 24  25      Fernando              174      Arias     fernando.arias@gmail.com
# 25  26        Raquel              179     Alonso      raquel.alonso@gmail.com
# 26  27         Marta              183    Vicente      marta.vicente@gmail.com
# 27  28         Maria              185       Díaz         maria.díaz@gmail.com
# 28  29       Beatriz              175      Ramos      beatriz.ramos@gmail.com
# 29  30         Maria              177      López        maria.lópez@gmail.com
# 30  31         Clara              178     Suárez       clara.suárez@gmail.com
# 31  32         Irene              180    Vicente      irene.vicente@gmail.com
# 32  33       Gabriel              181     Castro     gabriel.castro@gmail.com
# 33  34         Irene              155     Moreno       irene.moreno@gmail.com
# 34  35         Luisa              167  Fernández    luisa.fernández@gmail.com
# 35  36         Clara              163  Fernández    clara.fernández@gmail.com
# 36  37        Andrés              170      López       andrés.lópez@gmail.com
# 37  38        Silvia              152      Smith       silvia.smith@gmail.com
# 38  39           Eva               43     Torres         eva.torres@gmail.com
# 39  40           Eva               50    Sánchez        eva.sánchez@gmail.com
# 40  41         Diego               56      Evans        diego.evans@gmail.com
# 41  42         Diego               66    Mendoza      diego.mendoza@gmail.com
# 42  43       Ricardo               75     Wilson     ricardo.wilson@gmail.com
# 43  44        Andrés               84     Méndez      andrés.méndez@gmail.com
# 44  45         Elena               96      Smith        elena.smith@gmail.com
# 45  46         Maria              100    Jiménez      maria.jiménez@gmail.com
# 46  47        Alicia              108       Díaz        alicia.díaz@gmail.com
# 47  48         Mario              120     Wilson       mario.wilson@gmail.com
# 48  49          José              124     Wilson        josé.wilson@gmail.com
# 49  50           Ana              126     Thomas         ana.thomas@gmail.com
# 50  51       Antonio                5     Suárez     antonio.suárez@gmail.com
# 51  52        Alicia                7     Suárez      alicia.suárez@gmail.com
# 52  53         Sofia                8      Ramos        sofia.ramos@gmail.com
# 53  54     Alejandro                9     Suárez   alejandro.suárez@gmail.com
# 54  55         Diego               11    Sánchez      diego.sánchez@gmail.com
# 55  56      Santiago               12    Vicente   santiago.vicente@gmail.com
# 56  57       Beatriz               13    Mendoza    beatriz.mendoza@gmail.com
# 57  58        Isabel               14      Reyes       isabel.reyes@gmail.com
# 58  59          Raul               15     Romero        raul.romero@gmail.com
# 59  60         Irene               16      Gómez        irene.gómez@gmail.com
#
#    password        tel  birthdate avatar confirmed  \
# 0      None  657042370 1980-10-11   None         1
# 1      None  628069713 1981-03-05   None         1
# 2      None  612472809 1982-11-12   None         1
# 3      None  661070823 1979-08-28   None         0
# 4      None  660731374 1985-09-15   None         0
# 5      None  629968039 1978-11-30   None         0
# 6      None  629415962 1984-06-22   None         0
# 7      None  614253808 1985-03-05   None         1
# 8      None  688536659 1986-11-12   None         0
# 9      None  616824481 1983-08-28   None         1
# 10     None  699144351 1989-09-15   None         1
# 11     None  637275640 1982-11-30   None         0
# 12     None  691989983 1988-06-22   None         1
# 13     None  628808944 1989-03-05   None         1
# 14     None  626600448 1990-11-12   None         0
# 15     None  661850643 1987-08-28   None         1
# 16     None  683695939 1993-09-15   None         1
# 17     None  681587456 1986-11-30   None         0
# 18     None  692393409 1992-06-22   None         1
# 19     None  607734432 1993-03-05   None         0
# 20     None  607734432 1994-11-12   None         0
# 21     None  668735501 1991-08-28   None         1
# 22     None  621045613 1997-09-15   None         1
# 23     None  624263548 2003-09-15   None         1
# 24     None  677575858 2000-06-22   None         0
# 25     None  691839008 2001-03-05   None         0
# 26     None  614480853 1999-11-12   None         1
# 27     None  606494642 2002-08-28   None         0
# 28     None  656927156 2007-05-15   None         0
# 29     None  688837440 2007-02-03   None         0
# 30     None  621203387 2006-10-11   None         1
# 31     None  699566548 2006-07-25   None         1
# 32     None  621536083 2006-03-23   None         0
# 33     None  695814718 1980-10-11   None         1
# 34     None  686621084 1981-03-05   None         1
# 35     None  654216046 1982-11-12   None         0
# 36     None  613405047 1979-08-28   None         0
# 37     None  678055988 1985-09-15   None         1
# 38     None  621490482 1978-11-30   None         1
# 39     None  632930106 1984-06-22   None         1
# 40     None  674306256 1985-03-05   None         1
# 41     None  618721442 1986-11-12   None         0
# 42     None  609969437 1983-08-28   None         0
# 43     None  663817728 1989-09-15   None         0
# 44     None  644390188 1982-11-30   None         1
# 45     None  635548985 1988-06-22   None         0
# 46     None  656213249 1989-03-05   None         1
# 47     None  618225331 1990-11-12   None         1
# 48     None  646574417 1987-08-28   None         1
# 49     None  615905976 1993-09-15   None         0
# 50     None  621351986 1986-11-30   None         0
# 51     None  651065439 1992-06-22   None         1
# 52     None  684238225 1993-03-05   None         0
# 53     None  612230772 1994-11-12   None         1
# 54     None  661536987 1991-08-28   None         1
# 55     None  637166624 1997-09-15   None         1
# 56     None  685848824 1990-11-30   None         1
# 57     None  627913543 1996-06-22   None         1
# 58     None  648765274 1997-03-05   None         0
# 59     None  627921480 1998-11-12   None         1
#
#                                                  file       course  \
# 0                                                None         None
# 1                                                None         None
# 2                                                None         None
# 3                                                None         None
# 4                                                None         None
# 5                                                None         None
# 6                                                None         None
# 7                                                None         None
# 8                                                None         None
# 9                                                None         None
# 10                                               None         None
# 11                                               None         None
# 12                                               None         None
# 13                                               None         None
# 14                                               None         None
# 15                                               None         None
# 16                                               None         None
# 17                                               None         None
# 18                                               None         None
# 19                                               None         None
# 20                                               None         None
# 21                                               None         None
# 22                                               None         None
# 23  Persona educada y organizada. Ha estudiado inf...        Otros
# 24  Interesado en emprender en el sector de la aut...        Otros
# 25          El Open day le causó muy buena impresión.        Otros
# 26          El Open day le causó muy buena impresión.        Otros
# 27          El Open day le causó muy buena impresión.        Otros
# 28  Está estudiando el bachillerato de letras. Int...  1 Bachiller
# 29  Está estudiando el bachillerato de letras. Int...  1 Bachiller
# 30          El Open day le causó muy buena impresión.  2 Bachiller
# 31     Está estubiando el bachillerato de económicas.  2 Bachiller
# 32  Está estudiando el bachillerato de letras. Int...  2 Bachiller
# 33   Interesado en formarse en liderazgo de personas.         None
# 34                Está interesado en el grado de ADE.         None
# 35          Está interesado en el grado de Marketing.         None
# 36          Está interesado en el grado de Marketing.         None
# 37  Interesado en emprender en el sector de la aut...         None
# 38   Interesado en que su empresa sea miembro de MdE.         None
# 39          El Open day le causó muy buena impresión.         None
# 40          El Open day le causó muy buena impresión.         None
# 41  Nos pidió que le avisáramos para la próxima fe...         None
# 42  Nos pidió que le informáramos si salen nuevos ...         None
# 43  Interesado en emprender en el sector de la aut...         None
# 44  Nos pidió que le avisáramos para la próxima fe...         None
# 45  Nos pidió que le avisáramos para la próxima fe...         None
# 46  Nos pidió que le informáramos si salen nuevos ...         None
# 47          Está interesado en el grado de Marketing.         None
# 48  Está estudiando el bachillerato de letra. Inte...         None
# 49  Nos pidió que le avisáramos para la próxima fe...         None
# 50   Interesado en que su empresa sea miembro de MdE.         None
# 51  Nos pidió que le avisáramos para la próxima fe...         None
# 52                Está interesado en el grado de ADE.         None
# 53                Está interesado en el grado de ADE.         None
# 54  Nos pidió que le avisáramos para la próxima fe...         None
# 55  Nos pidió que le avisáramos para la próxima fe...         None
# 56  Nos pidió que le avisáramos para la próxima fe...         None
# 57  Nos pidió que le informáramos si salen nuevos ...         None
# 58          Está interesado en el grado de Marketing.         None
# 59                Está interesado en el grado de ADE.         None
#
#            country            interest  gender     catchment     career  \
# 0          Croatia      Emprendimiento  Female    Contratado      Grado
# 1            Spain           Inversión    Male    Contratado     Máster
# 2            Spain            Docencia    Male    Contratado     Máster
# 3            Spain  Nuevas tecnologías    Male    Contratado      Grado
# 4           Norway      Emprendimiento    Male    Contratado     Máster
# 5            Spain      Emprendimiento    Male    Contratado     Máster
# 6            Spain            Docencia    Male    Contratado      Grado
# 7            Spain            Finanzas    Male    Contratado      Grado
# 8          Ireland             Derecho  Female    Contratado      Grado
# 9            Spain    Recursos humanos    Male    Contratado      Grado
# 10           Spain             Derecho  Female    Contratado     Máster
# 11           Spain             Deporte  Female    Contratado     Máster
# 12           Spain             Deporte    Male    Contratado      Grado
# 13           Italy          Actualidad    Male    Contratado      Grado
# 14           Spain          Actualidad    Male    Contratado      Grado
# 15     Netherlands             Derecho    Male    Contratado     Máster
# 16           Spain             Deporte    Male    Contratado      Grado
# 17         Hungary             Derecho    Male    Contratado     Máster
# 18         Croatia            Docencia    Male    Contratado      Grado
# 19         Austria            Docencia    Male    Contratado     Máster
# 20          España            Docencia    Male    Contratado     Máster
# 21           Spain          Actualidad  Female    Contratado      Grado
# 22         Belgium          Actualidad    Male    Contratado      Grado
# 23           Spain  Nuevas tecnologías    Male     Asistente      Grado
# 24           Spain             Deporte    Male     Asistente      Grado
# 25          Monaco            Finanzas  Female    Interesado      Grado
# 26           Spain           Inversión  Female    Interesado      Grado
# 27          France                  IT  Female    Interesado      Grado
# 28           Spain  Nuevas tecnologías  Female    Interesado      Grado
# 29           Malta          Actualidad  Female    Interesado      Grado
# 30         Denmark  Nuevas tecnologías  Female   Matriculado      Grado
# 31           Spain            Finanzas  Female      Admitido      Grado
# 32           Spain             Deporte    Male  Entrevistado      Grado
# 33           Spain                  IT  Female      Admitido     Máster
# 34  Czech Republic             Derecho  Female    Interesado     Máster
# 35           Spain             Derecho  Female    Interesado     Máster
# 36           Spain    Recursos humanos    Male   Matriculado     Máster
# 37           Spain            Finanzas  Female     Asistente  Doctorado
# 38           Spain             Derecho  Female      Admitido     Máster
# 39           Spain                  IT  Female    Interesado     Máster
# 40         Iceland             Derecho    Male     Asistente  Doctorado
# 41         Croatia    Recursos humanos    Male    Interesado     Máster
# 42           Spain            Finanzas    Male    Interesado  Doctorado
# 43          Latvia             Derecho    Male   Matriculado     Máster
# 44         Denmark                  IT  Female      Admitido  Doctorado
# 45   Liechtenstein            Finanzas  Female    Interesado  Doctorado
# 46          Sweden            Finanzas  Female    Interesado     Máster
# 47          Norway            Docencia    Male   Matriculado     Máster
# 48           Spain           Inversión    Male      Admitido     Máster
# 49           Spain           Inversión  Female    Interesado     Máster
# 50           Spain                  IT    Male    Interesado  Doctorado
# 51           Spain           Inversión  Female     Asistente     Máster
# 52          Cyprus    Recursos humanos  Female      Admitido     Máster
# 53        Slovenia           Inversión    Male     Asistente  Doctorado
# 54  United Kingdom            Finanzas    Male  Entrevistado     Máster
# 55           Spain           Inversión    Male      Admitido      Grado
# 56           Spain             Deporte  Female    Interesado     Máster
# 57           Italy            Finanzas  Female    Interesado      Grado
# 58           Spain                  IT    Male     Asistente      Grado
# 59           Spain          Actualidad  Female      Admitido      Grado
#
#                    responsibility  area  createdAt
# 0                  Campus manager  None 2023-09-28
# 1            Gerente de Logística  None 2023-09-28
# 2            Gerente de Logística  None 2023-09-28
# 3            Gerente de Marketing  None 2023-09-28
# 4            Gerente de Marketing  None 2023-09-28
# 5                         Ponente  None 2023-09-28
# 6                      profesores  None 2023-09-28
# 7                      profesores  None 2023-09-28
# 8   Responsable de Área Bootcamps  None 2023-09-28
# 9   Responsable de Área grado ADE  None 2023-09-28
# 10    Responsables de Informatica  None 2023-09-28
# 11    Responsables de Informatica  None 2023-09-28
# 12    Responsables de Informatica  None 2023-09-28
# 13    Responsables de Informatica  None 2023-09-28
# 14    Responsables de Informatica  None 2023-09-28
# 15    Responsables de Informatica  None 2023-09-28
# 16    Responsables de Informatica  None 2023-09-28
# 17    Responsables de Informatica  None 2023-09-28
# 18    Responsables de Informatica  None 2023-09-28
# 19    Responsables de Informatica  None 2023-09-28
# 20    Responsables de Informatica  None 2023-09-28
# 21         Técnico de Informática  None 2023-09-28
# 22         Técnico de Informática  None 2023-09-28
# 23                         Alumno  None 2023-09-28
# 24                         Alumno  None 2023-09-28
# 25                         Alumno  None 2023-09-28
# 26                         Alumno  None 2023-09-28
# 27                         Alumno  None 2023-09-28
# 28                         Alumno  None 2023-09-28
# 29                         Alumno  None 2023-09-28
# 30                         Alumno  None 2023-09-28
# 31                         Alumno  None 2023-09-28
# 32                         Alumno  None 2023-09-28
# 33                            CEO  None 2023-09-28
# 34               Responsable RRHH  None 2023-09-28
# 35                 Gerente Fiscal  None 2023-09-28
# 36                         Ventas  None 2023-09-28
# 37                        Ponente  None 2023-09-28
# 38       Responsable técnico BBDD  None 2023-09-28
# 39                        Ponente  None 2023-09-28
# 40               Gerente Jurídico  None 2023-09-28
# 41                 Jefe de ventas  None 2023-09-28
# 42           Jefe de Departamento  None 2023-09-28
# 43                 Jefe de equipo  None 2023-09-28
# 44               Jefe de proyecto  None 2023-09-28
# 45                   Técnico RRHH  None 2023-09-28
# 46                        Ponente  None 2023-09-28
# 47              Técnico Márketing  None 2023-09-28
# 48                    Programador  None 2023-09-28
# 49                      Diseñador  None 2023-09-28
# 50                        Ponente  None 2023-09-28
# 51                 Administrativo  None 2023-09-28
# 52              Asistente técnico  None 2023-09-28
# 53                        Ponente  None 2023-09-28
# 54                 Producto owner  None 2023-09-28
# 55               Producto manager  None 2023-09-28
# 56       Coordinador de proyectos  None 2023-09-28
# 57        Gerente de contabilidad  None 2023-09-28
# 58                 Gerente fiscal  None 2023-09-28
# 59         Consultor de inversión  None 2023-09-28

# %% [markdown]
# <br>
#
# ### Poblar Tabla de Tokens

# %%
# create_table_sql = """
#     CREATE TABLE IF NOT EXISTS "Tokens" (
#         "id" SERIAL PRIMARY KEY,
#         "User_id" INT NOT NULL REFERENCES "Users"("id"),
#         "token" VARCHAR(255),
#         "createdAt" TIMESTAMP NOT NULL,
#         "updatedAt" TIMESTAMP NOT NULL
#     );
# """

# with eval(psycopg2_conn) as conn, conn.cursor() as cur:
#     cur.execute(create_table_sql)

# %%
# columnas = pd.read_sql_table('Tokens', con=engine).columns

# tokens_excel = pd.read_csv('../data/excel/Tokens.csv', index_col=0)
# tokens_excel['createdAt'] = pd.to_datetime(dt.date(dt.today()))
# tokens_excel['updatedAt'] = pd.to_datetime(dt.date(dt.today()))
# tokens_excel.columns = columnas
# tokens_excel = tokens_excel.drop('id', axis=1)
# tokens_excel

# %%
# tokens_excel.to_sql('Tokens', con=engine, if_exists='append', index=False)
# Out:
# 15

# %%
pd.read_sql_table('Tokens', con=engine)
# Out:
#     id  User_id                                              token  createdAt  \
# 0    1        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-28
# 1    2        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-28
# 2    3        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-28
# 3    4        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-28
# 4    5        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-28
# 5    6        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-28
# 6    7        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-28
# 7    8        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-28
# 8    9        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-28
# 9   10        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-28
# 10  11        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-28
# 11  12        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-28
# 12  13        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-28
# 13  14        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-28
# 14  15        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-28
#
#     updatedAt
# 0  2023-09-28
# 1  2023-09-28
# 2  2023-09-28
# 3  2023-09-28
# 4  2023-09-28
# 5  2023-09-28
# 6  2023-09-28
# 7  2023-09-28
# 8  2023-09-28
# 9  2023-09-28
# 10 2023-09-28
# 11 2023-09-28
# 12 2023-09-28
# 13 2023-09-28
# 14 2023-09-28

# %% [markdown]
# <br>
#
# ### Poblar Tabla de Roles

# %%
# create_table_sql = """
#     CREATE TABLE IF NOT EXISTS "Roles" (
#         "id" SERIAL PRIMARY KEY,
#         "User_id" INT NOT NULL REFERENCES "Users"("id"),
#         "type" VARCHAR(255),
#         "createdAt" TIMESTAMP NOT NULL,
#         "updatedAt" TIMESTAMP NOT NULL
#     );
# """

# with eval(psycopg2_conn) as conn, conn.cursor() as cur:
#     cur.execute(create_table_sql)

# %%
# columnas = pd.read_sql_table('Roles', con=engine).columns

# roles_excel = pd.read_csv('../data/excel/Role.csv')
# roles_excel['createdAt'] = pd.to_datetime(dt.date(dt.today()))
# roles_excel['updatedAt'] = pd.to_datetime(dt.date(dt.today()))
# roles_excel.columns = columnas
# roles_excel = roles_excel.drop('id', axis=1)
# roles_excel

# %%
# roles_excel.to_sql('Roles', con=engine, if_exists='append', index=False)
# Out:
# 60

# %%
pd.read_sql_table('Roles', con=engine)
# Out:
#     id  User_id        type  createdAt  updatedAt
# 0    1        1        User 2023-09-28 2023-09-28
# 1    2        2        User 2023-09-28 2023-09-28
# 2    3        3        User 2023-09-28 2023-09-28
# 3    4        4       Admin 2023-09-28 2023-09-28
# 4    5        5       Admin 2023-09-28 2023-09-28
# 5    6        6        User 2023-09-28 2023-09-28
# 6    7        7        User 2023-09-28 2023-09-28
# 7    8        8        User 2023-09-28 2023-09-28
# 8    9        9       Admin 2023-09-28 2023-09-28
# 9   10       10       Admin 2023-09-28 2023-09-28
# 10  11       11        User 2023-09-28 2023-09-28
# 11  12       12        User 2023-09-28 2023-09-28
# 12  13       13        User 2023-09-28 2023-09-28
# 13  14       14        User 2023-09-28 2023-09-28
# 14  15       15        User 2023-09-28 2023-09-28
# 15  16       16        User 2023-09-28 2023-09-28
# 16  17       17        User 2023-09-28 2023-09-28
# 17  18       18        User 2023-09-28 2023-09-28
# 18  19       19        User 2023-09-28 2023-09-28
# 19  20       20        User 2023-09-28 2023-09-28
# 20  21       21        User 2023-09-28 2023-09-28
# 21  22       22  Superadmin 2023-09-28 2023-09-28
# 22  23       23  Superadmin 2023-09-28 2023-09-28
# 23  24       24        User 2023-09-28 2023-09-28
# 24  25       25        User 2023-09-28 2023-09-28
# 25  26       26        User 2023-09-28 2023-09-28
# 26  27       27        User 2023-09-28 2023-09-28
# 27  28       28        User 2023-09-28 2023-09-28
# 28  29       29        User 2023-09-28 2023-09-28
# 29  30       30        User 2023-09-28 2023-09-28
# 30  31       31        User 2023-09-28 2023-09-28
# 31  32       32        User 2023-09-28 2023-09-28
# 32  33       33        User 2023-09-28 2023-09-28
# 33  34       34        User 2023-09-28 2023-09-28
# 34  35       35        User 2023-09-28 2023-09-28
# 35  36       36        User 2023-09-28 2023-09-28
# 36  37       37        User 2023-09-28 2023-09-28
# 37  38       38        User 2023-09-28 2023-09-28
# 38  39       39        User 2023-09-28 2023-09-28
# 39  40       40        User 2023-09-28 2023-09-28
# 40  41       41        User 2023-09-28 2023-09-28
# 41  42       42        User 2023-09-28 2023-09-28
# 42  43       43        User 2023-09-28 2023-09-28
# 43  44       44        User 2023-09-28 2023-09-28
# 44  45       45        User 2023-09-28 2023-09-28
# 45  46       46        User 2023-09-28 2023-09-28
# 46  47       47        User 2023-09-28 2023-09-28
# 47  48       48        User 2023-09-28 2023-09-28
# 48  49       49        User 2023-09-28 2023-09-28
# 49  50       50        User 2023-09-28 2023-09-28
# 50  51       51        User 2023-09-28 2023-09-28
# 51  52       52        User 2023-09-28 2023-09-28
# 52  53       53        User 2023-09-28 2023-09-28
# 53  54       54        User 2023-09-28 2023-09-28
# 54  55       55        User 2023-09-28 2023-09-28
# 55  56       56        User 2023-09-28 2023-09-28
# 56  57       57        User 2023-09-28 2023-09-28
# 57  58       58        User 2023-09-28 2023-09-28
# 58  59       59        User 2023-09-28 2023-09-28
# 59  60       60        User 2023-09-28 2023-09-28

# %% [markdown]
# <br>
#
# ### Poblar Tabla de EventUsers

# %%
# create_table_sql = """
#     CREATE TABLE IF NOT EXISTS "EventUsers" (
#         "id" SERIAL PRIMARY KEY,
#         "event_id" INT NOT NULL REFERENCES "Events"("id"),
#         "user_id" INT NOT NULL REFERENCES "Users"("id"),
#         "arriveTime" TIMESTAMP,
#         "qrtoken" VARCHAR(255),
#         "leaveTime" TIMESTAMP,
#         "createdAt" TIMESTAMP NOT NULL,
#         "updatedAt" TIMESTAMP NOT NULL
#     );
# """

# with eval(psycopg2_conn) as conn, conn.cursor() as cur:
#     cur.execute(create_table_sql)

# %%
# columnas = pd.read_sql_table('EventUsers', con=engine).columns

# roles_excel = pd.read_csv('../data/excel/Event_User.csv')
# roles_excel['createdAt'] = pd.to_datetime(dt.date(dt.today()))
# roles_excel['updatedAt'] = pd.to_datetime(dt.date(dt.today()))
# roles_excel.columns = columnas
# roles_excel = roles_excel.drop('id', axis=1)
# roles_excel

# %%
# roles_excel.to_sql('EventUsers', con=engine, if_exists='append', index=False)
# Out:
# 248

# %%
pd.read_sql_table('EventUsers', con=engine)
# Out:
#       id  event_id  user_id arriveTime qrtoken leaveTime  createdAt  updatedAt
# 0      1         1        2        NaT    None       NaT 2023-09-28 2023-09-28
# 1      2         1        4        NaT    None       NaT 2023-09-28 2023-09-28
# 2      3         1        7        NaT    None       NaT 2023-09-28 2023-09-28
# 3      4         1        8        NaT    None       NaT 2023-09-28 2023-09-28
# 4      5         1        9        NaT    None       NaT 2023-09-28 2023-09-28
# ..   ...       ...      ...        ...     ...       ...        ...        ...
# 243  244         6       53        NaT    None       NaT 2023-09-28 2023-09-28
# 244  245         6       54        NaT    None       NaT 2023-09-28 2023-09-28
# 245  246         6       58        NaT    None       NaT 2023-09-28 2023-09-28
# 246  247         6       59        NaT    None       NaT 2023-09-28 2023-09-28
# 247  248         6       60        NaT    None       NaT 2023-09-28 2023-09-28
#
# [248 rows x 8 columns]

# %% [markdown]
# <br>
#
# ### Poblar Tabla de Feedback

# %%
# create_table_sql = """
#     CREATE TABLE IF NOT EXISTS "Feedback" (
#         "id" SERIAL PRIMARY KEY,
#         "valoration" INT,
#         "eventUser_id" INT NOT NULL REFERENCES "EventUsers"("id"),
#         "comments" VARCHAR(255),
#         "createdAt" TIMESTAMP NOT NULL,
#         "updatedAt" TIMESTAMP NOT NULL
#     );
# """

# with eval(psycopg2_conn) as conn, conn.cursor() as cur:
#     cur.execute(create_table_sql)

# %%
pd.read_sql_table('Feedback', con=engine)
# Out:
# Empty DataFrame
# Columns: [id, valoration, eventUser_id, comments, createdAt, updatedAt]
# Index: []

# %% [markdown]
# <br>
#
# # Observar todas las tablas

# %%
tables = ['Events', 'Locations', 'Facilities', 'Location_amenities', 'Amenities', 
          'Contracted_services', 'Service_Provisions', 'Service_companies', 
          'EventUsers', 'Guests', 'Feedback', 
          'Users', 'Tokens', 'Roles', 
          'Organizations', 'Types', 'EducationalCenter']
dict_tables = {}

for table in tables:
    dict_tables[table] = pd.read_sql_table(table, con=engine)

for table in dict_tables.keys():
    display(dict_tables[table][:5])

print(len(tables))
# Out:
#    id  location_id            dateTime  duration_min       type banner  \
# 0   1           27 2023-10-23 16:00:00            90   Finanzas   None
# 1   2            6 2023-11-03 17:30:00            60  Marketing   None
# 2   3            5 2023-09-29 18:00:00           120   Docencia   None
# 3   4           28 2023-09-15 12:00:00            90         IT   None
# 4   5            5 2023-09-01 18:00:00            60  Liderazgo   None
#
#          speacker                                        description  \
# 0  Borja Astarloa  Borja Astarloa, director de JP Morgan, habla s...
# 1    Isabel López  Isabel López nos hablará sobre el desarrollo d...
# 2            EDEM  Aprovecha los días que EDEM abre sus puertas p...
# 3  Sònia Valiente  Sònia Valiente nos dará las claves más importa...
# 4    Mar Pedroche  Mar Pedroche nos mostrará las aplicaciones y p...
#
#                                                title  createdAt  updatedAt
# 0            Planteamientos financieros y económicos 2023-09-27 2023-09-27
# 1  Claves para mejorar la experiencia del cliente... 2023-09-27 2023-09-27
# 2                                 Open Day Grado ADE 2023-09-27 2023-09-27
# 3                 Comunicación en entornos digitales 2023-09-27 2023-09-27
# 4  Conocer herramientas que mejoran la productivi... 2023-09-27 2023-09-27
#    id  facility_id meeting_room  capacity            description  createdAt  \
# 0   1            1        P-001        50    Planta 0, Pasillo 1 2023-09-27
# 1   2            1        P-101        50    Planta 1, Pasillo 1 2023-09-27
# 2   3            1        P-201        50    Planta 2, Pasillo 1 2023-09-27
# 3   4            1        A-001        60  Planta 0, Auditorio 1 2023-09-27
# 4   5            1        A-101        60  Planta 1, Auditorio 1 2023-09-27
#
#    updatedAt
# 0 2023-09-27
# 1 2023-09-27
# 2 2023-09-27
# 3 2023-09-27
# 4 2023-09-27
#    id       name                                           address  createdAt  \
# 0   1       Edem             Plaça de L'aigua, s/n, 46024 Valencia 2023-09-27
# 1   2  Lanzadera  Carrer del Moll de la Duana, s/n, 46024 Valencia 2023-09-27
# 2   3     Angels                     Sc Puerto, 13, 46024 Valencia 2023-09-27
#
#    updatedAt
# 0 2023-09-27
# 1 2023-09-27
# 2 2023-09-27
#    id  location_id  amenities_id  createdAt  updatedAt
# 0   1            1             3 2023-09-27 2023-09-27
# 1   2            2             3 2023-09-27 2023-09-27
# 2   3            3             3 2023-09-27 2023-09-27
# 3   4            4             1 2023-09-27 2023-09-27
# 4   5            4             2 2023-09-27 2023-09-27
#    id       name  createdAt  updatedAt
# 0   1    Butacas 2023-09-27 2023-09-27
# 1   2      Atril 2023-09-27 2023-09-27
# 2   3   Pantalla 2023-09-27 2023-09-27
# 3   4  Proyector 2023-09-27 2023-09-27
#    id  service_id  event_id   cost  paid  service_company_id  createdAt  \
# 0   1           1         1  200.0   NaN                   1 2023-09-27
# 1   2           2         1    NaN   NaN                   9 2023-09-27
# 2   3           3         1  350.0   NaN                   7 2023-09-27
# 3   4           5         1  300.0   NaN                   3 2023-09-27
# 4   5           1         2  200.0   NaN                   1 2023-09-27
#
#    updatedAt
# 0 2023-09-27
# 1 2023-09-27
# 2 2023-09-27
# 3 2023-09-27
# 4 2023-09-27
#    id                  name  \
# 0   1  Servicio de cátering
# 1   2   Cobertura Logística
# 2   3      Material gráfico
# 3   4      Monaje de stands
# 4   5            Fotografía
#
#                                          description  createdAt  updatedAt
# 0           Servicio de café, refrescos y bocadillos 2023-09-27 2023-09-27
# 1     Servicio de recepción y apoyo a incidencias IT 2023-09-27 2023-09-27
# 2       Elaboración de Flyer y cartel 0,90 x 1,80 cm 2023-09-27 2023-09-27
# 3  Servicio, montaje, desmontaje y retirada de st... 2023-09-27 2023-09-27
# 4  Reportaje fotográfico de evento de duración má... 2023-09-27 2023-09-27
#    id                        name                  email        tel  \
# 0   1                    Colevisa  colevisa@colevisa.com  963169106
# 1   2                      Salsia         info@salsia.es  960089454
# 2   3              JMC Fotografos            info@jmc.es  963363914
# 3   4  Estudio fotografico Lorsil   fotolorsil@gmail.com  963345422
# 4   5                 MA's Events    masevents@gmail.com  662332287
#
#    speciality department  createdAt  updatedAt
# 0    catering     Ventas 2023-09-27 2023-09-27
# 1    catering     Ventas 2023-09-27 2023-09-27
# 2  fotografia     Ventas 2023-09-27 2023-09-27
# 3  fotografia     Ventas 2023-09-27 2023-09-27
# 4  montadores     Ventas 2023-09-27 2023-09-27
#    id  event_id  user_id arriveTime qrtoken leaveTime  createdAt  updatedAt
# 0   1         1        2        NaT    None       NaT 2023-09-27 2023-09-27
# 1   2         1        4        NaT    None       NaT 2023-09-27 2023-09-27
# 2   3         1        7        NaT    None       NaT 2023-09-27 2023-09-27
# 3   4         1        8        NaT    None       NaT 2023-09-27 2023-09-27
# 4   5         1        9        NaT    None       NaT 2023-09-27 2023-09-27
#    id  event_id             name                       email  createdAt  \
# 0   1         1   Antonio García   antoniogarcia@example.com 2023-09-27
# 1   2         1  Carmen Martínez  carmenmartinez@example.com 2023-09-27
# 2   3         1  Francisco López  franciscolopez@example.com 2023-09-27
# 3   4         1      María Pérez      mariaperez@example.com 2023-09-27
# 4   5         1     Juan Sánchez     juansanchez@example.com 2023-09-27
#
#    updatedAt
# 0 2023-09-27
# 1 2023-09-27
# 2 2023-09-27
# 3 2023-09-27
# 4 2023-09-27
# Empty DataFrame
# Columns: [id, valoration, eventUser_id, comments, createdAt, updatedAt]
# Index: []
#    id    name  organization_id    surname                      email password  \
# 0   1  Raquel                2    Cabrera   raquel.cabrera@gmail.com     None
# 1   2  Manuel                2     Torres    manuel.torres@gmail.com     None
# 2   3  Manuel                2    Johnson   manuel.johnson@gmail.com     None
# 3   4   Diego                2  Hernández  diego.hernández@gmail.com     None
# 4   5   Mario                2     Molina     mario.molina@gmail.com     None
#
#          tel  birthdate avatar confirmed  ... course  country  \
# 0  657042370 1980-10-11   None         0  ...   None  Croatia
# 1  628069713 1981-03-05   None         1  ...   None    Spain
# 2  612472809 1982-11-12   None         0  ...   None    Spain
# 3  661070823 1979-08-28   None         1  ...   None    Spain
# 4  660731374 1985-09-15   None         0  ...   None   Norway
#
#              interest  gender   catchment  career        responsibility  area  \
# 0      Emprendimiento  Female  Contratado   Grado        Campus manager  None
# 1           Inversión    Male  Contratado  Máster  Gerente de Logística  None
# 2            Docencia    Male  Contratado  Máster  Gerente de Logística  None
# 3  Nuevas tecnologías    Male  Contratado   Grado  Gerente de Marketing  None
# 4      Emprendimiento    Male  Contratado  Máster  Gerente de Marketing  None
#
#    createdAt  updatedAt
# 0 2023-09-27 2023-09-27
# 1 2023-09-27 2023-09-27
# 2 2023-09-27 2023-09-27
# 3 2023-09-27 2023-09-27
# 4 2023-09-27 2023-09-27
#
# [5 rows x 21 columns]
#    id  User_id                                              token  createdAt  \
# 0   1        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-27
# 1   2        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-27
# 2   3        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-27
# 3   4        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-27
# 4   5        7  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6N... 2023-09-27
#
#    updatedAt
# 0 2023-09-27
# 1 2023-09-27
# 2 2023-09-27
# 3 2023-09-27
# 4 2023-09-27
#    id  User_id   type  createdAt  updatedAt
# 0   1        1   User 2023-09-27 2023-09-27
# 1   2        2   User 2023-09-27 2023-09-27
# 2   3        3   User 2023-09-27 2023-09-27
# 3   4        4  Admin 2023-09-27 2023-09-27
# 4   5        5  Admin 2023-09-27 2023-09-27
#    id  type_id                                            name  \
# 0   1       44                                       Lanzadera
# 1   2      190                                            Edem
# 2   3       57                                  Angels Capital
# 3   4       88                                             AAA
# 4   5      170  ACS Actividades de Construccion y Servicios SA
#
#                             web                  email        tel position  \
# 0          https://lanzadera.es      info@lanzadera.es  963568585  General
# 1               https://edem.eu           info@edem.es  963531065  General
# 2  https://www.angelscapital.es  info@angelscapital.es  963568585  General
# 3   https://www.triplea.edem.es        triplea@edem.es  963531065  General
# 4      https://www.grupoacs.com        acs@empresa.com  913439200  General
#
#                             sector  createdAt  updatedAt
# 0                   Emprendimiento 2023-09-27 2023-09-27
# 1                        Educación 2023-09-27 2023-09-27
# 2                        Inversión 2023-09-27 2023-09-27
# 3  organización sin ánimo de lucro 2023-09-27 2023-09-27
# 4                     Industriales 2023-09-27 2023-09-27
#    id  organization_id                name  createdAt  updatedAt
# 0   1                1  Marina de Empresas 2023-09-27 2023-09-27
# 1   2                2  Marina de Empresas 2023-09-27 2023-09-27
# 2   3                3  Marina de Empresas 2023-09-27 2023-09-27
# 3   4                4  Marina de Empresas 2023-09-27 2023-09-27
# 4   5                5                Otro 2023-09-27 2023-09-27
#    id  type_id     name  createdAt  updatedAt
# 0   1      175  Colegio 2023-09-27 2023-09-27
# 1   2      177  Colegio 2023-09-27 2023-09-27
# 2   3      178  Colegio 2023-09-27 2023-09-27
# 3   4      180  Colegio 2023-09-27 2023-09-27
# 4   5      181  Colegio 2023-09-27 2023-09-27
# 17
